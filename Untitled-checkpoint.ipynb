# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
train_df = pd.read_csv("train.csv")

# %%
train_df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                       Name   Sex  \
# count    891.000000  891.000000  891.000000                        891   891
# unique          NaN         NaN         NaN                        891     2
# top             NaN         NaN         NaN  Sjostedt, Mr. Ernst Adolf  male
# freq            NaN         NaN         NaN                          1   577
# mean     446.000000    0.383838    2.308642                        NaN   NaN
# std      257.353842    0.486592    0.836071                        NaN   NaN
# min        1.000000    0.000000    1.000000                        NaN   NaN
# 25%      223.500000    0.000000    2.000000                        NaN   NaN
# 50%      446.000000    0.000000    3.000000                        NaN   NaN
# 75%      668.500000    1.000000    3.000000                        NaN   NaN
# max      891.000000    1.000000    3.000000                        NaN   NaN
#
# ...

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_df.hist(bins=50,figsize=(20,15))
plt.show()

# %%
pd.set_option('display.max_rows', None)
train_df.Age.value_counts(bins=10)
# Out:
# (16.336, 24.294]    177
# (24.294, 32.252]    169
# (32.252, 40.21]     118
# (40.21, 48.168]      70
# (0.339, 8.378]       54
# (8.378, 16.336]      46
# (48.168, 56.126]     45
# (56.126, 64.084]     24
# (64.084, 72.042]      9
# (72.042, 80.0]        2
# Name: Age, dtype: int64

# %%
train_df.Fare.value_counts(bins=10)
# Out:
# (-0.513, 51.233]      732
# (51.233, 102.466]     106
# (102.466, 153.699]     31
# (204.932, 256.165]     11
# (256.165, 307.398]      6
# (461.096, 512.329]      3
# (153.699, 204.932]      2
# (409.863, 461.096]      0
# (358.63, 409.863]       0
# (307.398, 358.63]       0
# Name: Fare, dtype: int64

# %%
train_df.Fare.hist(bins=10)
plt.show()

# %%
train_df.boxplot(column="Fare")

# %%
train_df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
label = train_df["Survived"].copy()

# %%
corr_matrix = train_df.corr()

# %%
corr_matrix
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
corr_matrix['Survived'].sort_values(ascending=False)
# Out:
# Survived       1.000000
# Fare           0.257307
# Parch          0.081629
# PassengerId   -0.005007
# SibSp         -0.035322
# Age           -0.077221
# Pclass        -0.338481
# Name: Survived, dtype: float64

# %%
sns.catplot(x="Pclass",y= "Age", hue= "Sex", kind= "box", data= train_df)

# %%
train_df_copy= train_df.copy()

# %%
train_df_copy
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
Three_female_df= train_df.loc[(train_df['Pclass']== 3) & (train_df['Sex']== 'female')]

# %%
Three_female_df
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 14            15         0       3
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# 68            69         1       3
# 71            72         0       3
# 79            80         1       3
# 82            83         1       3
# 85            86         1       3
# 100          101         0       3
# 106          107         1       3
# 109          110         1       3
# ...

# %%
Three_female_df['Age'].mean()
# Out:
# 21.75

# %%
Three_female_df['Age'].median()
# Out:
# 21.5

# %%
Three_female_df['Age'].fillna(Three_female_df['Age'].median(),inplace= True)
# Out:
# C:\Users\B.J.PATIL\Anaconda3\lib\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
Three_female_df
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 14            15         0       3
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# 68            69         1       3
# 71            72         0       3
# 79            80         1       3
# 82            83         1       3
# 85            86         1       3
# 100          101         0       3
# 106          107         1       3
# 109          110         1       3
# ...

# %%
Three_female_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          138
# Embarked         0
# dtype: int64

# %%
train_df= train_df.merge(Three_female_df, how= 'inner', on= 'PassengerId')
